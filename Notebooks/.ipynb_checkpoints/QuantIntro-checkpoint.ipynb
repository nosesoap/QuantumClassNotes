# %%
# INTRODUCTION TESTING CODE

from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator

# Create a quantum circuit with one qubit
qc = QuantumCircuit(2)

# Apply a Hadamard gate to create superposition
qc.h(0)
qc.cx(0, 1) # add a Control NOT to creation correlation between qubit 0 to qubit 1

# Add measurement operations to all qubits
qc.measure_all()

# Draw the circuit
qc.draw("mpl")

# Run the circuit on a simulator
simulator = AerSimulator()
job = simulator.run(qc, shots=4096)
result = job.result()
counts = result.get_counts()

print(counts)
# Our outputs should be close to half and half
# Out:
# {'00': 2018, '11': 2078}

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator

# Create a one-qubit circuit
qc = QuantumCircuit(1)
qc.h(0)
qc.measure_all()

# Run the circuit on a simulator
simulator = AerSimulator()
job = simulator.run(qc, shots=4096)
result = job.result()
counts = result.get_counts()

print(counts)
# Out:
# {'1': 2040, '0': 2056}

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

# Run this once in a trusted personal environment.
# Replace the placeholders with your own IBM Quantum Platform credentials.
# ACCOUNT DATA HIDDEN

# Later, load the saved default account like this:
service = QiskitRuntimeService()
print("IBM Quantum service loaded successfully.")
# Out:
# IBM Quantum service loaded successfully.

# %%
from qiskit import QuantumCircuit
from qiskit.transpiler import generate_preset_pass_manager
from qiskit_ibm_runtime import QiskitRuntimeService, SamplerV2 as Sampler

# Create a simple measured circuit
qc = QuantumCircuit(1)
qc.h(0)
qc.measure_all()

# Load saved IBM Quantum credentials
service = QiskitRuntimeService()

# Select a real quantum backend
backend = service.least_busy(
    operational=True,
    simulator=False,
    min_num_qubits=1
)

print("Selected backend:", backend.name)

# Transpile the circuit for the selected backend
pm = generate_preset_pass_manager(
    backend=backend,
    optimization_level=1
)
isa_circuit = pm.run(qc)

# Submit the circuit with SamplerV2
sampler = Sampler(mode=backend)
job = sampler.run([isa_circuit], shots=1024)

print("Job ID:", job.job_id())

# Retrieve results when the job completes
result = job.result()
pub_result = result[0]
counts = pub_result.data.meas.get_counts()

print(counts)
# Out:
# Selected backend: ibm_marrakesh
# Job ID: da1n0maein7c73bdkcvg
# {'1': 518, '0': 506}

# %%
# POST INTRODUCTION REMINDERS
#
# STUDY THE MATH AND SYMBOLS
# RUN THE CODE
# TWEAK AND PREDICT
# COMPARE SIMULATION TO THEORY
# TEST HARDWARE ONLY IF SIMULATION WORKS
# TAKE OBSERVATIONS, ERRORS, CONCLUSIONS

# %%
# Standard Notes
# Superposition — a qubit can occupy multiple basis states simultaneously.
# Interference — amplitudes can reinforce or cancel one another.
# Entanglement — composite systems can exhibit correlations with no classical analogue.
# Measurement — amplitudes are converted into observable probabilities.

# Example: Bell State
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector

qc = QuantumCircuit(2)
qc.h(0)
qc.cx(0, 1)

print(qc)
print(Statevector.from_instruction(qc))

# Using the print feature! Makes a text based vector displaying vector stuff
# Out:
#      ┌───┐
# q_0: ┤ H ├──■──
#      └───┘┌─┴─┐
# q_1: ─────┤ X ├
#           └───┘
# Statevector([0.70710678+0.j, 0.        +0.j, 0.        +0.j,
#              0.70710678+0.j],
#             dims=(2, 2))
